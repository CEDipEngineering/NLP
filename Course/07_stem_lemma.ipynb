# %%
import matplotlib.pyplot as plt
plt.style.use('default')
import nltk
from nltk.corpus import stopwords
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

df = pd.read_csv('./datasets/IMDB Dataset.csv')
reviews = [s for s in df['review']]
sw = stopwords.words('english')
vectorizer = CountVectorizer(max_features=5000, stop_words=sw, binary=True)
x = vectorizer.fit_transform(reviews)
x = np.sum(x, axis=0)

# %%
tuplas = [ (x[0,vectorizer.vocabulary_[i]], i) for i in vectorizer.vocabulary_.keys() ]
tuplas_ordenadas = sorted(tuplas, reverse=True) # reverse=True pede uma ordenação em ordem decrescente
palavras = [ t[1] for t in tuplas_ordenadas ]
contagens = [ t[0] for t in tuplas_ordenadas ]

n_palavras = 60
eixo_x = np.arange(n_palavras)
plt.figure(figsize=(14,3))
plt.bar(eixo_x[0:n_palavras], contagens[0:n_palavras])
plt.xticks(eixo_x[0:n_palavras], palavras[0:n_palavras], rotation=70)
plt.show()

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer("english")
reviews = [s for s in df['review']]
for n in range (len(reviews)):
    reviews[n] = " ".join([stemmer.stem(p) for p in reviews[n].split()])

sw = stopwords.words('english')
vectorizer = CountVectorizer(max_features=5000, stop_words=sw, binary=True)
x = vectorizer.fit_transform(reviews)
x = np.sum(x, axis=0)

# %%
tuplas = [ (x[0,vectorizer.vocabulary_[i]], i) for i in vectorizer.vocabulary_.keys() ]
tuplas_ordenadas = sorted(tuplas, reverse=True) # reverse=True pede uma ordenação em ordem decrescente
palavras = [ t[1] for t in tuplas_ordenadas ]
contagens = [ t[0] for t in tuplas_ordenadas ]

n_palavras = 60
eixo_x = np.arange(n_palavras)
plt.figure(figsize=(14,3))
plt.bar(eixo_x[0:n_palavras], contagens[0:n_palavras])
plt.xticks(eixo_x[0:n_palavras], palavras[0:n_palavras], rotation=70)
plt.show()

# %%
from nltk.stem import WordNetLemmatizer
nltk.download("omw-1.4")

lemmatizer = WordNetLemmatizer()
reviews = [s for s in df['review']]
for n in range (len(reviews)):
    reviews[n] = " ".join([lemmatizer.lemmatize(p,'v') for p in reviews[n].split() if p not in sw])

sw = stopwords.words('english')
vectorizer = CountVectorizer(max_features=5000, stop_words=sw, binary=True)
x = vectorizer.fit_transform(reviews)
x = np.sum(x, axis=0)
# Out:
# [nltk_data] Downloading package omw-1.4 to /home/user/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
tuplas = [ (x[0,vectorizer.vocabulary_[i]], i) for i in vectorizer.vocabulary_.keys() ]
tuplas_ordenadas = sorted(tuplas, reverse=True) # reverse=True pede uma ordenação em ordem decrescente
palavras = [ t[1] for t in tuplas_ordenadas ]
contagens = [ t[0] for t in tuplas_ordenadas ]

n_palavras = 60
eixo_x = np.arange(n_palavras)
plt.figure(figsize=(14,3))
plt.bar(eixo_x[0:n_palavras], contagens[0:n_palavras])
plt.xticks(eixo_x[0:n_palavras], palavras[0:n_palavras], rotation=70)
plt.show()

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize("characters")
# Out:
# 'character'

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer("portuguese")
x ="Era uma vez numa terra distante um grande hipopotamo branco e feliz lá ele sorria muito e lutava karatê com seus amigos".split()
for w in x:
    print(stemmer.stem(w))
# Out:
# era
# uma
# vez
# num
# terr
# distant
# um
# grand
# hipopotam
# branc
# e
# feliz
# lá
# ele
# sorr
# muit
# e
# lut
# karat
# com
# seus
# amig

# %%
from nltk.stem import RSLPStemmer
nltk.download('rslp')
stemmer = RSLPStemmer()
[print(i, "->", stemmer.stem(i)) for i in ["printar"]]
# Out:
# printar -> print
# [nltk_data] Downloading package rslp to /home/user/nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# [None]
